# %%
import sys
sys.path.append("..")

import numpy as np
import pandas as pd
from reco_systems.filter import filter_df
from reco_systems.user_game_matrix import *
from reco_systems.CF_knn import *
from reco_systems.evaluation import *
from copy import *
import matplotlib.pyplot as plt
from itertools import product

# %load_ext autoreload
# %autoreload 2

folder = "../images/error_metrics/hide_users"

# %%
folder_db = "../database_cleaned"
avis_clean  = pd.read_csv(f"{folder_db}/avis_clean.csv", index_col=0)
jeux_clean  = pd.read_csv(f"{folder_db}/jeux_clean.csv", index_col=0)
users       = pd.read_csv(f"{folder_db}/users.csv", index_col=0)

min_reviews = 10 # change to set one
rev_filter = filter_df(avis_clean, min_reviews)
center_rev_filter, _ = center_score(rev_filter)
# Out:
# 11201 10549
# 2086 2464
# 1800 2399
# 1792 2397
# 1791 2396

# %% [markdown]
# # Baseline Performances

# %% [markdown]
# ## Full matrix

# %% [markdown]
# ## 50-200 reviews

# %%
folder = "../images/error_metrics/hide_users"

rmse_c = plt.imread(f"{folder}/cos_rmse_50_200.png")
mae_c = plt.imread(f"{folder}/cos_mae_50_200.png")
boxplot_c = plt.imread(f"{folder}/cos_base_50_200_bigk.png")

rmse_e = plt.imread(f"{folder}/eucl_rmse_50_200.png")
mae_e = plt.imread(f"{folder}/eucl_mae_50_200.png")
boxplot_e = plt.imread(f"{folder}/eucl_base_50_200.png")

images = [rmse_c, boxplot_c, mae_c, rmse_e, boxplot_e, mae_e]

fig, ax = plt.subplots(2, 3)

for i, j in product(range(2), range(3)):
    print(i, j, i * 3 + j)
    ax[i, j].imshow(images[i * 3 + j])
    ax[i, j].axis("off")

fig.set_size_inches(18.5, 10.5, forward=True)
fig.set_dpi(100)
fig.tight_layout()
# Out:
# 0 0 0
# 0 1 1
# 0 2 2
# 1 0 3
# 1 1 4
# 1 2 5

# %% [markdown]
# ## 200+ reviews

# %%
folder = "../images/error_metrics/hide_users"

rmse_c = plt.imread(f"{folder}/cos_rmse_top76.png")
mae_c = plt.imread(f"{folder}/cos_mae_top76.png")
boxplot_c = plt.imread(f"{folder}/cos_base_top76.png")

rmse_e = plt.imread(f"{folder}/eucl_rmse_top76.png")
mae_e = plt.imread(f"{folder}/eucl_mae_top76.png")
boxplot_e = plt.imread(f"{folder}/eucl_base_top76.png")

images = [rmse_c, boxplot_c, mae_c, rmse_e, boxplot_e, mae_e]

fig, ax = plt.subplots(2, 3)

for i, j in product(range(2), range(3)):
    print(i, j, i * 3 + j)
    ax[i, j].imshow(images[i * 3 + j])
    ax[i, j].axis("off")

fig.set_size_inches(18.5, 10.5, forward=True)
fig.set_dpi(100)
fig.tight_layout()
# Out:
# 0 0 0
# 0 1 1
# 0 2 2
# 1 0 3
# 1 1 4
# 1 2 5

# %% [markdown]
# # Centered Performances

# %% [markdown]
# ## Full matrix

# %%
#TODO

# %% [markdown]
# ## 50-200 reviews

# %%
folder = "../images/error_metrics/hide_users"

rmse_c = plt.imread(f"{folder}/cos_center_rmse_50-200.png")
mae_c = plt.imread(f"{folder}/cos_center_mae_50-200.png")
boxplot_c = plt.imread(f"{folder}/cos_center_50_200.png")

rmse_e = plt.imread(f"{folder}/eucl_center_rmse_50-200.png")
mae_e = plt.imread(f"{folder}/eucl_center_mae_50-200.png")
boxplot_e = plt.imread(f"{folder}/eucl_centered_50_200.png")

images = [rmse_c, boxplot_c, mae_c, rmse_e, boxplot_e, mae_e]

fig, ax = plt.subplots(2, 3)

for i, j in product(range(2), range(3)):
    print(i, j, i * 3 + j)
    ax[i, j].imshow(images[i * 3 + j])
    ax[i, j].axis("off")

fig.set_size_inches(18.5, 10.5, forward=True)
fig.set_dpi(100)
fig.tight_layout()
# Out:
# 0 0 0
# 0 1 1
# 0 2 2
# 1 0 3
# 1 1 4
# 1 2 5

# %% [markdown]
# ## 200+ reviews

# %%
folder = "../images/error_metrics/hide_users"

rmse_c = plt.imread(f"{folder}/cos_center_rmse_top76.png")
mae_c = plt.imread(f"{folder}/cos_center_mae_top76.png")
boxplot_c = plt.imread(f"{folder}/cos_center_top76.png")

rmse_e = plt.imread(f"{folder}/eucl_center_rmse_top76.png")
mae_e = plt.imread(f"{folder}/eucl_center_mae_top76.png")
boxplot_e = plt.imread(f"{folder}/eucl_center_top76.png")

images = [rmse_c, boxplot_c, mae_c, rmse_e, boxplot_e, mae_e]

fig, ax = plt.subplots(2, 3)

for i, j in product(range(2), range(3)):
    print(i, j, i * 3 + j)
    ax[i, j].imshow(images[i * 3 + j])
    ax[i, j].axis("off")

fig.set_size_inches(18.5, 10.5, forward=True)
fig.set_dpi(100)
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 9
#       7 rmse_e = plt.imread(f"{folder}/eucl_center_rmse_top76.png")
#       8 mae_e = plt.imread(f"{folder}/eucl_center_mae_top76.png")
# ----> 9 boxplot_e = plt.imread(f"{folder}/eucl_centered_top76.png")
#      11 images = [rmse_c, boxplot_c, mae_c, rmse_e, boxplot_e, mae_e]
#      13 fig, ax = plt.subplots(2, 3)
#
# File c:\Python312\Lib\site-packages\matplotlib\pyplot.py:2597, in imread(fname, format)
#    2593 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2594 def imread(
#    2595         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2596 ) -> np.ndarray:
# -> 2597     return matplotlib.image.imread(fname, format)
#
# File c:\Python312\Lib\site-packages\matplotlib\image.py:1544, in imread(fname, format)
#    1537 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1538     # Pillow doesn't handle URLs directly.
#    1539     raise ValueError(
#    1540         "Please open the URL for reading and pass the "
#    1541         "result to Pillow, e.g. with "
#    1542         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1543         )
# -> 1544 with img_open(fname) as image:
#    1545     return (_pil_png_to_float_array(image)
#    1546             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1547             pil_to_array(image))
#
# File c:\Python312\Lib\site-packages\PIL\ImageFile.py:126, in ImageFile.__init__(self, fp, filename)
#     122 self.decodermaxblock = MAXBLOCK
#     124 if is_path(fp):
#     125     # filename
# --> 126     self.fp = open(fp, "rb")
#     127     self.filename = fp
#     128     self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/error_metrics/hide_users/eucl_centered_top76.png'
